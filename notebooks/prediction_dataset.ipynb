# %%
import os 
import glob
import random

import torch
from torch.utils.data import DataLoader
import torchvision.transforms.functional as F
import numpy as np
from PIL import Image
from skimage import io

from matplotlib import pyplot as plt

#from utils.model import pad_image

# %%
# %cd ../
# Out:
# /Users/anatolijpotapov/.CMVolumes/Анатолий Потапов/inpainting_FRRN

# %%
from utils.general import get_config
from data.dataset import Dataset

# %%
config = get_config('./experiments/local/config.yml')

# %%
dataset = Dataset(config, training=True)
# Out:
# Loading file list...  ../Datasets/Huawei/DATASET_INPAINTING/train_gt

# %%
iterator = dataset.create_iterator(2)

# %%
batch = next(iterator)
plt.imshow(batch['image'][0].permute(1,2,0))
plt.show()
plt.imshow(batch['mask'][0].permute(1,2,0)[:,:,0])
plt.show()
plt.imshow(batch['constant_mask'][0].permute(1,2,0)[:,:,0])
plt.show()
